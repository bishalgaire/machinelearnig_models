# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('Position_Salaries.csv')

# %%
dataset,head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-50cc75dde480> in <module>()
# ----> 1 dataset,head()
#
# NameError: name 'head' is not defined

# %%
X=dataset.iloc[:,1].values#create a matrix X and Y
Y=dataset.iloc[:,2].values
#we should convert X vector to matrix form
X=dataset.iloc[:,1:2].values#only on column so vector

# %% [markdown]
# we dont have enougn data so we will not do spliting

# %%
plt.scatter(X,Y)
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %%
#first we will try simple linear regression
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(X,Y)#tranning model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.scatter(X,Y)
plt.plot(X,linear.predict(X),color='red')
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# this model doesnot fit all the model.so we will try for polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features=PolynomialFeatures(degree=2)
X_poly=poly_features.fit_transform(X)

# %%
X_poly
# Out:
# array([[  1.,   1.,   1.],
#        [  1.,   2.,   4.],
#        [  1.,   3.,   9.],
#        [  1.,   4.,  16.],
#        [  1.,   5.,  25.],
#        [  1.,   6.,  36.],
#        [  1.,   7.,  49.],
#        [  1.,   8.,  64.],
#        [  1.,   9.,  81.],
#        [  1.,  10., 100.]])

# %% [markdown]
# fitting poly features in linear model

# %%
linear_poly=LinearRegression()
linear_poly.fit(X_poly,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.scatter(X,Y)
plt.plot(X,linear_poly.predict(poly_features.fit_transform(X)),color='yellow')
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# increasing the degree.for degree =4  all the data gets fit well

# %%
poly_features=PolynomialFeatures(degree=4)
X_poly=poly_features.fit_transform(X)
linear_poly.fit(X_poly,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.scatter(X,Y)
X_grid=np.arange(min(X),max(X),0.1)
X_grid=X_grid.reshape((len(X_grid),1))
plt.plot(X,linear_poly.predict(poly_features.fit_transform(X)),color='yellow')
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()
